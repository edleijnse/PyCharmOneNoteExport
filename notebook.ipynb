# %%
import importlib
import onenote_extractor as one

ONE_FILE = r"D:\OneNote\Paspoort.one"

# %%
doc = one.load(ONE_FILE)
print("Loaded.")

# %%
import os
section_name = os.path.splitext(os.path.basename(ONE_FILE))[0]
pages = one.extract_pages(doc, section_name)
print(f"Extracted {len(pages)} page(s).")

# %%
one.print_pages(pages)
